# %% [markdown]
# # Explore time stamp files

# %%
import os
import pickle

# %%
raw_data_path = '/mnt/lustre02/work/ka1176/shared_data/2021-ai4food/raw_data/'

planet_train1 = 'ref_fusion_competition_south_africa_train_source_planet/ref_fusion_competition_south_africa_train_source_planet_34S_19E_258N_asc_34S_19E_258N_2017'
planet_train2 = 'ref_fusion_competition_south_africa_train_source_planet/ref_fusion_competition_south_africa_train_source_planet_34S_19E_258N_asc_34S_19E_259N_2017'

sentinel1_train1 = 'ref_fusion_competition_south_africa_train_source_sentinel_1/ref_fusion_competition_south_africa_train_source_sentinel_1_34S_19E_258N_asc_34S_19E_258N_2017'
sentinel1_train2 = 'ref_fusion_competition_south_africa_train_source_sentinel_1/ref_fusion_competition_south_africa_train_source_sentinel_1_34S_19E_259N_asc_34S_19E_259N_2017'

sentinel2_train1 = 'ref_fusion_competition_south_africa_train_source_sentinel_2/ref_fusion_competition_south_africa_train_source_sentinel_2_34S_19E_258N_34S_19E_258N_2017'
sentinel2_train2 = 'ref_fusion_competition_south_africa_train_source_sentinel_2/ref_fusion_competition_south_africa_train_source_sentinel_2_34S_19E_259N_34S_19E_259N_2017'

# %%
folders = [sentinel1_train1, sentinel1_train2, sentinel2_train1, sentinel2_train2]

# %%
for folder in folders:
    with open(os.path.join(raw_data_path, folder, 'timestamp.pkl'), 'rb') as f:
        timestamps = pickle.load(f)
        print(folder.split('/')[-1])
        print(f'nr of timestamps: {len(timestamps)}')
        
        for t in range(len(timestamps)):
            print(timestamps[t].day)
        print()
# Out:
# ref_fusion_competition_south_africa_train_source_sentinel_1_34S_19E_258N_asc_34S_19E_258N_2017
# nr of timestamps: 41
# 1
# 8
# 13
# 20
# 25
# 2
# 7
# 14
# 19
# 26
# 31
# 7
# 12
# 19
# 24
# 1
# 6
# 13
# 18
# 25
# 30
# 6
# 11
# 18
# 23
# 30
# 4
# 11
# 16
# 23
# 28
# 5
# 10
# 17
# 22
# 29
# 3
# 10
# 15
# 22
# 27
#
# ref_fusion_competition_south_africa_train_source_sentinel_1_34S_19E_259N_asc_34S_19E_259N_2017
# nr of timestamps: 41
# 1
# 8
# 13
# 20
# 25
# 2
# 7
# 14
# 19
# 26
# 31
# 7
# 12
# 19
# 24
# 1
# 6
# 13
# 18
# 25
# 30
# 6
# 11
# 18
# 23
# 30
# 4
# 11
# 16
# 23
# 28
# 5
# 10
# 17
# 22
# 29
# 3
# 10
# 15
# 22
# 27
#
# ref_fusion_competition_south_africa_train_source_sentinel_2_34S_19E_258N_34S_19E_258N_2017
# nr of timestamps: 76
# 1
# 8
# 11
# 18
# 21
# 28
# 1
# 8
# 11
# 18
# 21
# 28
# 31
# 7
# 10
# 17
# 20
# 27
# 30
# 2
# 5
# 7
# 10
# 12
# 15
# 17
# 20
# 22
# 25
# 27
# 30
# 4
# 6
# 9
# 11
# 14
# 16
# 19
# 21
# 24
# 26
# 29
# 31
# 5
# 8
# 10
# 15
# 18
# 23
# 25
# 28
# 30
# 3
# ...
